# %%
import pandas as pd

# %%
s1 = pd.Series([71, 84, 56, 23, 89, 36, 67])

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
print(s1)
# Out:
# 0    71
# 1    84
# 2    56
# 3    23
# 4    89
# 5    36
# 6    67
# dtype: int64

# %%
s2 = pd.Series([71, 84, 56, 23, 89, 36, 67], index = ["Harry", "Shubh", "Rohan", "Aakash", "Divya", "Arjun", "Arsh"])

# %%
print(s2)
# Out:
# Harry     71
# Shubh     84
# Rohan     56
# Aakash    23
# Divya     89
# Arjun     36
# Arsh      67
# dtype: int64

# %%
data = {
    "name" : ["Alice", "Bob", "Charlie"],
    "age" : [25, 30, 35],
    "city" : ["Delhi", "Mumbai", "Bangalore"]
}

# %%
df1 = pd.DataFrame(data)
print(df1)
# Out:
#       name  age       city
# 0    Alice   25      Delhi
# 1      Bob   30     Mumbai
# 2  Charlie   35  Bangalore

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df1.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')
